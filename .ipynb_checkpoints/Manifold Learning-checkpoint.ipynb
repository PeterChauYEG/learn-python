# %% [markdown]
# # In-depth: manifold Learning
# While PCA works well, it does not perform well when there are nonlinear relationships in the data
#
# We can use manifold learning to address this.
# - a class of unsupervised estimators which describe data as low-dimensional manifolds embedded in high-dimensional spaces
# - we can transform the 2d object in 3d space
# - manifold learning seeks to learn about the fundamental 2d nature

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %% [markdown]
# ## Manifold learning: "HELLO"
# - generate 2d data to define a manifold

# %%
def make_hello(N=1000, rseed=42):
    # make a plot with "HELLO" text; save as PNG
    fig, ax = plt.subplots(figsize=(4, 1))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
    ax.axis('off')
    ax.text(0.5, 0.4, 'HELLO', va='center', ha='center', weight='bold', size=85)
    fig.savefig('hello.png')
    plt.close(fig)
    
    # open this PNG and draw random points from it
    from matplotlib.image import imread
    data = imread('hello.png')[::-1, :, 0].T
    rng = np.random.RandomState(rseed)
    X = rng.rand(4 * N, 2)
    i, j = (X * data.shape).astype(int).T
    mask = (data[i, j] < 1)
    X = X[mask]
    X[:, 0] *= (data.shape[0] / data.shape[1])
    X = X[:N]
    return X[np.argsort(X[:, 0])]

# %%
# Call the function and visualize the resulting data
X = make_hello(1000)
colorize = dict(c=X[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.scatter(X[:, 0], X[:, 1], **colorize)
plt.axis('equal')
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# (-0.20835420840544649,
#  4.203971195560074,
#  0.0065469735014421979,
#  1.0131108713369323)

# %% [markdown]
# The output is a 2d set of points that draws the word "HELLO"
#
# ## Multidimensional Scaling (MDS)
# We see that the choice of x and y values are not the most funamental description of the data.
# -we can scale, shrink, rotate
# - data is fundamentally the same

# %%
def rotate(X, angle):
    theta = np.deg2rad(angle)
    R = [[np.cos(theta), np.sin(theta)],
        [-np.sin(theta), np.cos(theta)]]
    return np.dot(X, R)

X2 = rotate(X, 20) + 5
plt.scatter(X2[:, 0], X2[:, 1], **colorize)
plt.axis('equal')
# Out:
# (4.4989615766372077, 8.8520470086595182, 4.966146169080087, 7.3008522354940162)
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Distance between each point in the dataset is fundamental.
#
# USe pairwise_distances on the data
# - for N points, construct an NxN array
# - each entry is the distance between point i and j

# %%
from sklearn.metrics import pairwise_distances
D = pairwise_distances(X)
D.shape
# Out:
# (1000, 1000)

# %% [markdown]
# Visualize it

# %%
plt.imshow(D, zorder=2, cmap='Blues', interpolation='nearest')
plt.colorbar()
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# We can also dothis for the rotated and translated data
# - it is the same

# %%
D2 = pairwise_distances(X2)
np.allclose(D, D2)
# Out:
# True

# %% [markdown]
# The distance matrix gives a representation that is invariant to rotations and translations
# - it shows that we have not lost any visible sign of the insteresting structure
#
# Lets try to convert the distance matrix back into x and y coordinates
# - use the multidimensional scaling algorithm
# - given a distance matix, recover dimensional coordinate representation

# %%
from sklearn.manifold import MDS
model = MDS(n_components=2, dissimilarity='precomputed', random_state=1)
out = model.fit_transform(D)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal')
# Out:
# (-2.0689911607606497,
#  2.1295670913108506,
#  -1.375442829763204,
#  1.3753014910770802)
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The algorithm recovers 1 of the possible 2d cordinate representations of the data.
#
# ## MDS as machine learning
# we can compute distance matrics from data in any dimension.
# - instead of rotating the data in 2d, we can project it into 3d

# %%
def random_projection(X, dimension=3, rseed=42):
    assert dimension >= X.shape[1]
    rng = np.random.RandomState(rseed)
    C = rng.randn(dimension, dimension)
    e, V = np.linalg.eigh(np.dot(C, C.T))
    return np.dot(X, V[:X.shape[1]])

X3 = random_projection(X, 3)
X3.shape
# Out:
# (1000, 3)

# %% [markdown]
# visualize the points

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.scatter3D(X3[:, 0], X3[:, 1], X3[:, 2],
            **colorize)
ax.view_init(azim=70, elev=50)
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Use this 3d data to compute the distance matrix
# - determine the optimal 2d embedding for this distance matrix
# - result recovers the representation for the original data

# %%
model = MDS(n_components=2, random_state=1)
out3 = model.fit_transform(X3)
plt.scatter(out3[:, 0], out3[:, 1], **colorize)
plt.axis('equal')
# Out:
# (-2.0689911607606541,
#  2.1295670913109301,
#  -1.3754428297632169,
#  1.375301491077457)
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Essentially, the goal is: given high-dimensional embedded data, seek a low-dimensional representation of the data that preserves certian relationships
#
# ## Nonlinear embeddings: WHere MDS fails
# MDS breaksdown when the embedding is nonlinear
#
# Consider the following:
# - take an input and contort it into an 'S' shape in 3d

# %%
def make_hello_s_curve(X):
    t = (X[:, 0] - 2) * 0.75 * np.pi
    x = np.sin(t)
    y = X[:, 1]
    z = np.sign(t) * (np.cos(t) - 1)
    return np.vstack((x, y, z)).T

XS = make_hello_s_curve(X)

# %% [markdown]
# The embedding here is much more complicated

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.scatter3D(XS[:, 0], XS[:, 1], XS[:, 2],
            **colorize)
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The fundamental relationship is still there but it's been transfromed in a nonlinear way.
# - wrapped up into an S
#
# We are unable to unwrap it with MDS

# %%
from sklearn.manifold import MDS
model = MDS(n_components=2, random_state=2)
outS = model.fit_transform(XS)
plt.scatter(outS[:, 0], outS[:, 1], **colorize)
plt.axis('equal')
# Out:
# (-2.1365118799328533,
#  1.9513645526827357,
#  -1.964487771705596,
#  1.7955931060507271)
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Nonlinear Manifolds: Locally linear embedding
# - the problem is that MDS trieds to preserve distances between faraway points when constructing the embedding
# - what if we only preserve distances between nearby points
#
# We can use Locally Linear Embedding
# - preserve only distances between neighboring points

# %%
from sklearn.manifold import LocallyLinearEmbedding
model = LocallyLinearEmbedding(n_neighbors=100, n_components=2, method='modified',
                              eigen_solver='dense')
out = model.fit_transform(XS)

fig, ax = plt.subplots()
ax.scatter(out[:, 0], out[:, 1], **colorize)
ax.set_ylim(0.15, -0.15)
# Out:
# (0.15, -0.15)
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Although distorted, we still get the original relationship
#
# ## Some thoughts on manifold methods
# Tend to be finicky so are often only used for simple qualitative visualization of high-dimensional data
#
# Some challanges that make Manifild learning poor in comparision to PCA:
#     - no good framework for handling missing data
#     - noise can short-circuit the effectiveness
#     - dependent on # of neighbours chosen
#     - optimal number of outputs is hard to determine
#     - meaning of embedded dimensions not always clear
#     - computationally expensive
#
# MDS' ability to preserve nonlinear relations is it's best quality
#
# ## Example: Isomap on Faces
# - Manifold learning is often used in understanding the relationship between high-dimensional datapoints
# - lets apply isomap on face data

# %%
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=30)
faces.data.shape
# Out:
# (2370, 2914)

# %% [markdown]
# We have 2370 images with 2914 pixels each. That's 2914d-space.
#
# Visualize some of the images

# %%
fig, ax = plt.subplots(4, 8, subplot_kw=dict(xticks=[], yticks=[]))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gray')

# %% [markdown]
# We want to plot low-dimensional embedding of the data to leanr the fundamental relationship between images
#
# Lets computes the PCA and examine the explained variance ratio
# - this will give an idea of how many linear features are requried to describe the data

# %%
from sklearn.decomposition import RandomizedPCA
model = RandomizedPCA(100).fit(faces.data)
plt.plot(np.cumsum(model.explained_variance_ratio_))
plt.xlabel('n components')
plt.ylabel('cumulative variance')
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:52: DeprecationWarning: Class RandomizedPCA is deprecated; RandomizedPCA was deprecated in 0.18 and will be removed in 0.20. Use PCA(svd_solver='randomized') instead. The new implementation DOES NOT store whiten ``components_``. Apply transform to get them.
#   warnings.warn(msg, category=DeprecationWarning)
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# We can see that 100 components is required to preserve 90% of the variance
# - the data is intrinsically very high dimensional
#
# This means that nonlinear manifold embeddings like LLE and Isomap can be helpful

# %%
from sklearn.manifold import Isomap
model = Isomap(n_components=2)
proj = model.fit_transform(faces.data)
proj.shape
# Out:
# (2370, 2)

# %% [markdown]
# the output is a 2d projection of all the input images.
#
# - output the image thumbnails at the locations of the projections

# %%
from matplotlib import offsetbox

def plot_components(data, model, images=None, ax=None,
                    thumb_frac=0.05, cmap='gray'):
    ax = ax or plt.gca()
    
    proj = model.fit_transform(data)
    ax.plot(proj[:, 0], proj[:, 1], '.k')
    
    if images is not None:
        min_dist_2 = (thumb_frac * max(proj.max(0) - proj.min(0))) ** 2
        shown_images = np.array([2 * proj.max(0)])
        for i in range(data.shape[0]):
            dist = np.sum((proj[i] - shown_images) ** 2, 1)
            if np.min(dist) < min_dist_2:
                # don't show points that are too close
                continue
            shown_images = np.vstack([shown_images, proj[i]])
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(images[i], cmap=cmap),
                                      proj[i])
            ax.add_artist(imagebox)

# %% [markdown]
# Call the function

# %%
fig, ax = plt.subplots(figsize=(10,10))
plot_components(faces.data,
               model=Isomap(n_components=2),
               images=faces.images[:, ::2, ::2])
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The frist 2 isomap dimensions seem to describe global image features

# %% [markdown]
# ## Example: Visualizing structure in digits
# Examine MNIST (28x28) with manifold learning for visualization

# %%
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')
mnist.data.shape
# Out:
# (70000, 784)

# %%
fig, ax = plt.subplots(6, 8, subplot_kw=dict(xticks=[], yticks=[]))
for i, axi in enumerate(ax.flat):
    axi.imshow(mnist.data[1250 * i].reshape(28, 28), cmap='gray_r')

# %% [markdown]
# We can see differant writing styles.
#
# Use a manifold learning projection across the data
# - only use 1/30 here

# %%
data = mnist.data[::30]
target = mnist.target[::30]

model = Isomap(n_components=2)
proj = model.fit_transform(data)
plt.scatter(proj[:,0], proj[:, 1], c=target, cmap=plt.cm.get_cmap('jet', 10))
plt.colorbar(ticks=range(10))
plt.clim(-0.5, 9.5)
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The relationship between numbers are shown but this very crowded.
#
# Look at a single number at time

# %%
from sklearn.manifold import Isomap

# choose 1/4 of '1' to project
data = mnist.data[mnist.target == 1][::4]

fig, ax = plt.subplots(figsize=(10, 10))
model = Isomap(n_neighbors=5, n_components=2, eigen_solver='dense')
plot_components(data, model, images=data.reshape((-1, 28, 28)),
               ax=ax, thumb_frac=0.05, cmap='gray_r')
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# This gives us an idea about the variety of forms the number '1' can take
#
# It can also help to ID outliers.
